# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
companies = open("companies.txt").read().splitlines()

for company in companies:
    ticker = yf.Ticker(company)

    stock_df = ticker.history(start='2001-01-01')

    stock_df['Close'].plot()

# %%
stock_df
# Out:
#                 Open      High       Low     Close   Volume  Dividends  \
# Date
# 2001-01-02  1.635688  1.635688  1.618700  1.621127   511227        0.0
# 2001-01-03  1.616273  1.647822  1.611420  1.630834   410443        0.0
# 2001-01-04  1.650249  1.650249  1.638114  1.638114   131459        0.0
# 2001-01-05  1.684225  1.701213  1.684225  1.689078  1118858        0.0
# 2001-01-08  1.693932  1.708493  1.689078  1.693932   153368        0.0
# ...              ...       ...       ...       ...      ...        ...
# 2021-06-21  5.900000  6.030000  5.900000  5.990000    60200        0.0
# 2021-06-22  5.990000  6.100000  5.900000  6.100000   517100        0.0
# 2021-06-23  6.230000  6.330000  6.200000  6.230000   111200        0.0
# 2021-06-24  6.350000  6.500000  6.350000  6.500000    47200        0.0
# 2021-06-25  6.510000  6.590000  6.500000  6.510000    39600        0.0
#
#             Stock Splits
# Date
# 2001-01-02           0.0
# 2001-01-03           0.0
# ...
